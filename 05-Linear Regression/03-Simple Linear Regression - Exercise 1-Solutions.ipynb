# %% [markdown]
# # SIMPLE LINEAR REGRESSION ON FUEL CONSUMPTION DATASET

# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# - You have been hired as a consultant to a major Automotive Manufacturer and you have been tasked to develop a model to predict the impact of increasing the vehicle horsepower (HP) on fuel economy (Mileage Per Gallon (MPG)). You gathered the data:
# - Data set:
#     - Independant variable X: Vehicle Horse Power
#     - Dependant variable Y: Mileage Per Gallon (MPG)

# %% [markdown]
# # STEP #1: LIBRARIES IMPORT

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # STEP #2: IMPORT DATASET

# %%
fueleconomy_df = pd.read_csv('FuelEconomy.csv')

# %%
fueleconomy_df.head(100)
# Out:
#     Horse Power  Fuel Economy (MPG)
# 0    118.770799           29.344195
# 1    176.326567           24.695934
# 2    219.262465           23.952010
# 3    187.310009           23.384546
# 4    218.594340           23.426739
# ..          ...                 ...
# 95   162.810542           27.418661
# 96   266.869640           15.989945
# 97   243.831211           19.253375
# 98   140.959803           29.515593
# 99   184.123053           25.196097
#
# [100 rows x 2 columns]

# %%
fueleconomy_df.head(5)
# Out:
#    Horse Power  Fuel Economy (MPG)
# 0   118.770799           29.344195
# 1   176.326567           24.695934
# 2   219.262465           23.952010
# 3   187.310009           23.384546
# 4   218.594340           23.426739

# %%
fueleconomy_df.tail(5)
# Out:
#     Horse Power  Fuel Economy (MPG)
# 95   162.810542           27.418661
# 96   266.869640           15.989945
# 97   243.831211           19.253375
# 98   140.959803           29.515593
# 99   184.123053           25.196097

# %%
fueleconomy_df.describe()
# Out:
#        Horse Power  Fuel Economy (MPG)
# count   100.000000          100.000000
# mean    213.676190           23.178501
# std      62.061726            4.701666
# min      50.000000           10.000000
# 25%     174.996514           20.439516
# 50%     218.928402           23.143192
# 75%     251.706476           26.089933
# max     350.000000           35.000000

# %%
fueleconomy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Horse Power         100 non-null    float64
#  1   Fuel Economy (MPG)  100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %% [markdown]
# # STEP#3: VISUALIZE DATASET

# %%
fueleconomy_df.head(4)
# Out:
#    Horse Power  Fuel Economy (MPG)
# 0   118.770799           29.344195
# 1   176.326567           24.695934
# 2   219.262465           23.952010
# 3   187.310009           23.384546

# %%
sns.jointplot(x = 'Horse Power', y = 'Fuel Economy (MPG)', data = fueleconomy_df)

# %%
sns.jointplot(x = 'Fuel Economy (MPG)', y = 'Horse Power', data = fueleconomy_df)

# %%
sns.pairplot(fueleconomy_df)

# %%
sns.lmplot(x = 'Horse Power', y =  'Fuel Economy (MPG)', data = fueleconomy_df)

# %%
sns.lmplot(x = 'Fuel Economy (MPG)', y =  'Horse Power', data = fueleconomy_df)

# %% [markdown]
# # STEP#4: CREATE TESTING AND TRAINING DATASET

# %%
X = fueleconomy_df[['Horse Power']]

# %%
y = fueleconomy_df['Fuel Economy (MPG)']

# %%
X
# Out:
#     Horse Power
# 0    118.770799
# 1    176.326567
# 2    219.262465
# 3    187.310009
# 4    218.594340
# ..          ...
# 95   162.810542
# 96   266.869640
# 97   243.831211
# 98   140.959803
# 99   184.123053
#
# [100 rows x 1 columns]

# %%
y
# Out:
# 0     29.344195
# 1     24.695934
# 2     23.952010
# 3     23.384546
# 4     23.426739
#         ...
# 95    27.418661
# 96    15.989945
# 97    19.253375
# 98    29.515593
# 99    25.196097
# Name: Fuel Economy (MPG), Length: 100, dtype: float64

# %%
X.shape
# Out:
# (100, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
X_train.shape
# Out:
# (70, 1)

# %%
X_test.shape
# Out:
# (30, 1)

# %% [markdown]
# # STEP#5: TRAIN THE MODEL

# %%
X_train.shape
# Out:
# (70, 1)

# %%
X_test.shape
# Out:
# (30, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression(fit_intercept = True)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coeff (m):', regressor.coef_)
print('Linear Model Coeff (b):', regressor.intercept_)
# Out:
# Linear Model Coeff (m): [-0.0724083]
# Linear Model Coeff (b): 38.73022535693224

# %% [markdown]
# # STEP#6: TEST THE MODEL

# %%
y_predict = regressor.predict(X_test)
y_predict
# Out:
# array([24.47596108, 18.26733295, 21.94200661, 20.5250049 , 25.81039182,
#        22.85380352, 29.12384767, 23.19976833, 22.48599736, 23.39928098,
#        26.94139119, 17.6675784 , 24.13079661, 14.71249477, 31.0362965 ,
#        30.07477943, 16.10319642, 20.44333702, 19.40664904, 21.109823  ,
#        20.94966904, 18.09903087, 25.08088279, 28.56176062, 24.89307474,
#        23.37365354, 24.31028389, 26.03350906, 20.57679255, 29.20548465])

# %%
y_test
# Out:
# 46    24.355851
# 33    15.676316
# 27    24.829824
# 56    22.965773
# 25    23.719583
# 2     23.952010
# 45    26.778148
# 76    22.183092
# 84    21.701202
# 14    25.341892
# 95    27.418661
# 51    17.873266
# 58    22.937653
# 86    15.837968
# 87    31.722566
# 29    30.392613
# 32    15.618956
# 39    20.407571
# 96    15.989945
# 24    21.623369
# 66    19.139999
# 57    18.878350
# 64    23.114161
# 23    28.882081
# 17    24.989630
# 63    21.726252
# 55    23.011194
# 72    26.057085
# 53    20.291766
# 93    29.397567
# Name: Fuel Economy (MPG), dtype: float64

# %%
plt.scatter(X_train, y_train, color = 'gray')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.xlabel('Horse Power (HP)')
plt.ylabel('MPG')
plt.title('HP vs. MPG (Training Set)')
# Out:
# Text(0.5, 1.0, 'HP vs. MPG (Training Set)')

# %%
plt.scatter(X_test, y_test, color = 'gray')
plt.plot(X_test, regressor.predict(X_test), color = 'blue')
plt.xlabel('Horse Power (HP)')
plt.ylabel('MPG')
plt.title('HP vs. MPG (Testing Set)')
# Out:
# Text(0.5, 1.0, 'HP vs. MPG (Testing Set)')

# %%
HP = 500
# MPG?

# %%
MPG = regressor.predict([[HP]])
MPG
# Out:
# /Users/loandoan/Opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.5260765])

# %% [markdown]
# # GREAT JOB
